# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/train.csv")

df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # Initial Check

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# Id                 0
# dtype: int64

# %% [markdown]
# # Handling Missing Values

# %%
none_cols = [
    "PoolQC", "Alley", "Fence", "MiscFeature",
    "FireplaceQu", "GarageType", "GarageFinish",
    "GarageQual", "GarageCond", "BsmtQual",
    "BsmtCond", "BsmtExposure", "BsmtFinType1",
    "BsmtFinType2", "MasVnrType", "LotFrontage",
    "GarageYrBlt", "MasVnrArea", "Electrical"
]

for col in none_cols:
    if col in df.columns:
        df[col] = df[col].fillna("None")

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# All missing values have been handled sucessfully

# %% [markdown]
# # Remove Outliers

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="GrLivArea", y="SalePrice", data=df)
plt.title("Before Outlier Removal")
plt.savefig("../reports/figures/before_outlier_removal.png")
plt.show()
plt.close()

# %%
df = df[~((df["GrLivArea"] > 4000) & (df["SalePrice"] < 300000))]

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="GrLivArea", y="SalePrice", data=df)
plt.title("After Outlier Removal")
plt.savefig("../reports/figures/after_outlier_removal.png")
plt.show()
plt.close()

# %% [markdown]
# Outlier removed to improve model performance

# %%
df.shape
# Out:
# (1458, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1458.000000  1458.000000  1458.000000    1458.000000  1458.000000
# mean    730.251715    56.893004    69.655693   10459.936900     6.093964
# std     421.601532    42.329437    21.042480    9859.198156     1.376369
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.250000    20.000000    60.000000    7544.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9475.000000     6.000000
# 75%    1094.750000    70.000000    79.000000   11600.000000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1458.000000  1458.000000   1458.000000  1458.000000  1458.000000  ...
# mean      5.576132  1971.218107   1984.834019   102.189986   438.827160  ...
# std       1.113359    30.193754     20.641760   179.109864   432.969094  ...
# ...

# %% [markdown]
# # Saving processed data

# %%
df.to_csv("../data/proceed/train_clean.csv", index=False)

# %% [markdown]
# # Summary
# - Removed unnecessary columns (Id)
# - Handled missing values using domain knowledge
# - Filled categorical and numerical values appropriately
# - Removed outliers
